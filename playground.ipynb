# %%
from matplotlib import pyplot as plt
import numpy as np
import scipy.stats as st

# %%
x = np.random.uniform(-10,10,10000000)
p = st.norm.pdf(x,0,1)
p
indexes = p > np.random.uniform(0,1,len(x))
x = x[indexes]
p = p[indexes]
plt.hist(x,bins=100,density=True)
plt.plot(np.linspace(-4,4,20),st.norm.pdf(np.linspace(-4,4,20),0,1))
1
# Out:
# 1
